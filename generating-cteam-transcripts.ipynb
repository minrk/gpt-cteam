# %% [markdown]
# # Generating transcripts for The "C" Team
#
# Model generated [on colaboratory](https://colab.research.google.com/drive/1Up9uwclJ4wYm9MFJhoI0_BNBqPeuY-vb), derived from [this example](https://colab.research.google.com/drive/1VLG8e7YSEwypxU-noRNhsv5dW4NfTGce) by [Max Woolf](http://minimaxir.com/).
#
# Training data was available manual transcripts from YouTube videos for [The "C" Team](http://www.acq-inc.com/cteam), which is only the first six episodes, plus Anchors Aweigh part 2.

# %% [markdown]
# Load the trained C-team model in the repo

# %%
import gpt_2_simple as gpt2
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='cteam')

# %% [markdown]
# Define a `generate` function with defaults for generating text from the model with a given prompt.
#
# The default is to generate 250 words, sampling four different times.

# %%
def generate(prefix, temperature=0.7, nsamples=4,
             batch_size=4, length=250, **kwargs):
    while nsamples % batch_size:
        batch_size -= 1
        
    return gpt2.generate(
        sess,
        run_name='cteam',
        temperature=temperature,
        prefix=prefix,
        nsamples=nsamples,
        batch_size=batch_size,
        length=length,
        **kwargs
    )

# %% [markdown]
# We can see what it thinks would start with Jerry

# %%
generate("jerry:", temperature=0.7)
# Out:
# jerry: wow.
# kate: that is a ten. i would take another ten.
# jerry: yeah, let's see it!
# kate: so this is going to be a
# long standing policy at the helm of this ship,
# be it as a last resort,
# to just remove all trace of any kind
# of ownership of this entity.
# which for a vagrant person like yourself, is a long way
# off reaching a commercial operation.
# and which is the intention of the structure
# you are trying to create?
# jerry: obviously.
# kate: certainly.
# jerry: you don't intend on building a harbor.
# jerry: you don't, patrick.
# kate: i'm more inclined to go with the harbor.
# since i don't see any reason why
# anybody would want to live in the first place,
# and i don't see any reason why harbor life wouldn't
# help them in some way.
# and i don't mean in a literal sense, but as a sonic
# symbol, as opposed to simply as a name.
# jerry: yeah, exactly.
# kate: i think of it as a sonic
# sy
# ====================
#
# jerry: but somehow they are. it's like.
# amy: that's how i like to play.
# kate: yeah, exactly.
# kate: i'm gonna...
# kate: try to do some of that.
# amy: yeah.
# amy: so i look at the cat and i go...
# jerry: just try to catch it?
# amy: catch it like a leaf.
# kate: yeah, i just try to catch it like a leaf
# and i throw it right back.
# amy: but this time i will disadvantage
# this attack.
# jerry: you have--
# kris: i have the ability to
# configure a pendragon moment (laughs)
# amy: she can now move through
# the space of any solid object.
# jerry: no.
# kris: it's like a...
# amy: pendragon moment, she can now see
# just inside the door--
# sort of on the edge,
# and just behind the edge of the table
# grabbing as much as you can,
# and then using your ranged action to
# strike the bolt.
# which is a dark green.
# kris: hmm.
# jerry:
# ====================
#
# jerry: (stammers)
# kate: (laughs)
# kris: "i don't know about that."
# kate: "our decisionist is in..."
# jerry: "too...good a good..."
# "we are here to help."
# kate: "oh, i see."
# jerry: "you are here to assist,"
# "the free will of these dwarves!"
# amy: "ah...to help one another!"
# jerry: "the natural order of things is..."
# jerry: "there's things that can
# help out stronger."
# amy: " free will you say?
# ryan: i say, "thank you."
# jerry: "it's been a pleasure."
# jerry: "i will repair the damage."
# amy: "am i--"
# ryan: is my strength above board and the armor?
# jerry: "yes. i can say that."
# amy: "that's good advice. good advice."
# kris: "could you tell me about this armor?"
# jerry: "this item?"
# jerry: "this armor."
# jerry: "never wear this armor."
# kris: "
# ====================
#
# jerry: no, no. like you're looking at it, like you have this invaluable insight,
# jerry: by the way, everyone else is just sort of like
# "i dunno..."
# kris: i kick the door in and i go,
# kris: "that's not gonna help anything."
# jerry: "whoa! whoa, kickin' kickin'."
# amy: haw!
# kris: "that's not gonna help anything, right?"
# ryan: "yeah."
# kate: "are you kidding me?
# - yeah. that's not gonna help anything."
# kris: "you... you... you know what?"
# jerry: just kick the door in and
# you get a little whiff of faerie fire.
# kris: "that's for sure."
# jerry: no, no, no. like you got
# a 10 to hit? that is not going to do anything.
# kris: "even with the fire, kickin' kickin'."
# jerry: no...
# amy: hmm.
# jerry: no, it's going to do something!
# kris: "even with the fire..."
# should
# ====================

# %% [markdown]
# Increasing the temperature makes the prompts more random

# %%
generate("jerry:", temperature=1.0, nsamples=1)
# Out:
# jerry: yeah, yeah.
# jerry: they're all here.
# amy: delightful.
# jerry: rosie beestinger!
# hey!
# jerry: i'm jerriford k. horkim: our heroes...
# kate: heroes from the official mouth!
# jerry: i'm also jerriford k. horkim: the heroes...
# from the original mouth.
# kate: heroes!
# kris: fan made!
# kris: all i can do is smile.
# (laughter)
# jerry: ugh...
# but it's a good sad story about a rogue.
# ryan: a... (@natural_selection)
# natural selection #7
# jerry: aww...
# good shit.
# ryan: can i pop my head out of this story?
# or is that gonna be kanye talking about?
# jerry: no, not now.
# donaar blit'zen.
# kris: hah. i'm not even gonna do that.
# so this is not a...
# it's not like the other films
# that are using this technique.
# it's not like the gold and gems
# that you

# %% [markdown]
# Reducing temperature results in a lot of repetition

# %%
generate("jerry:", temperature=0.4, nsamples=1)
# Out:
# jerry: yeah, yeah.
# kris: oh, they're so dense.
# jerry: the book says, "collective torment."
# kris: yeah.
# jerry: "collective torment?"
# jerry: "hmm..."
# jerry: "collective torment..."
# jerry: "i've never heard of it."
# "collective torment is a very powerful spell."
# kris: "you used to be."
# "well, i'm no expert on dire beasts."
# jerry: "but i always know how to get lucky."
# kris: "you're one of the only people i know who was
# like a centaur or something."
# "and i was like, 'what do you know of that?'"
# "people you know, i've been doing this for a long time."
# "and i always come up on them."
# "just because they have something nice."
# patrick: "they're all we have."
# kate: (laughs)
# kris: "they're all we have."
# kate: (laughs)
# patrick: "you all have um..."
# jerry: "collective torment is a very powerful spell

# %% [markdown]
# What does it think each of the players would say?

# %%
generate("ryan:", length=100, nsamples=2)
generate("amy:", length=100, nsamples=2)
generate("kate:", length=100, nsamples=2)
generate("kris:", length=100, nsamples=2)
# Out:
# r: "i don't know. i hope so."
# kate: "i'm just getting excited."
# amy: "i'm watching this."
# kate: "right."
# amy: "it's a great show. i'm watching."
# kate: "okay."
# amy: "yeah. go."
# kate: "i think that maybe"
# kate: "you're singing from the same tree
# that he is climbing down."
# kate:
# ====================
#
# r: yeah!
# kate: the smart one.
# jerry: yeah, yeah. it's the whole...
# kate: the 'n' box?
# jerry: yeah, yeah. exactly.
# jerry: so these hollow, fruitless prophecies
# and demands from the sides of these carts.
# you know?
# amy: prophey those were real.
# jerry: yeah, yeah. and you just--you're just like
# just waiting to see how
# ====================
#
# a: (laughs)
# amy: "i think she likes us."
# jerry: yeah.
# kate: "i think you like us!"
# amy: i just get excited!
# (laughter)
# amy: "i think i'm smart, ugly, and very sexy."
# jerry: she looks like she's trying to get
# jerry: yeah. she's just sort of gliding across the dock
# amy: like her bearings just straighten out?
# jerry
# ====================
#
# a: "i know. i know.
# everything's going to be okay."
# kate: "you're very, very smart."
# amy: "mhmm."
# amy: "and these mice are just
# just going to be friends
# with your life. i don't know
# what the hell they're doing here."
# kate: "i see."
# amy: "but."
# kate: "they're not friends of ours."
# amy: "well,
# ====================
#
# kate: make that yarn.
# kate: yeah, yeah.
# kris: oh no, it's a 25.   ryan: what?
# jerry: walnut's at 3?   kate: oh you're gonna roll a 20?
# kate: proud.
# jerry: proud.   kris: you beat it.
# kate: oh you're gonna roll 20 too? nice.
# patrick: that's beautiful.   kate
# ====================
#
# kate: oh no.
# kate: not yet.
# jerry: not yet.
# amy: so they're fresh off their greatsword.
# jerry: they're up on their haunches.
# kate: mmhmm.
# jerry: but you can see--
# you can see that they are full of mice.
# and you can see that they are performing
# a ritual that will make all the mice in the party.
# the release of which you can hear.
# ====================
#
# kris: yeah but not to get distracted
# kris: like, i mean you still have one turn
# amy: right, two days until the test. let's do it.
# kris: sure, whenever you guys back off.
# kate: okay.
# kris: so i back it up.
# (laughter)
# kris: i go right into it.
# the test is over.
# kate: oh...! that's great.
# kris: so we
# ====================
#
# kris: that was a long time ago.
# jerry: right? it was a long time ago.
# kris: what is it?     jerry: yeah.
# kris: alright.
# jerry: alright. turn around.
# kris: ambrosia is upon u.
# jerry: absolutely.
# kris: alright, so i turn to the knight and i say,
# jerry: "don't worry, my cousin."
# kris
# ====================

# %% [markdown]
# We can prompt it with a favorite line:

# %%
generate("kris: hello, friend", temperature=0.7, nsamples=3)
# Out:
# kris: hello, friend.
# jerry:    ryan:    kris: i'm on hold.
# amy: you never know.    kate: never know. out.
# amy: gotcha.
# ryan: you're welcome.
# kris: i'll take whatever it is.
# ryan: hey, i didn't know if you could only do one turn at a show
# ryan: yeah, i can do that.
# kate: i got a big old sword.
# ryan: i said, "thriss!"
# (laughter)
# kris: oh my, threshold one.
# kris: let me do a thurst!
# i'll do a thurst, and then i'll go,
# "i'm gonna make you a deal."
# ryan: say, "hold up! i'm gonna
# be your hostage. i'm gonna be your client."
# say, "the deal is done."
# slip your hand right out of the deal.
# (laughter)
# amy: flip the deal!
# kris: i did it. i did it.
# kris: "now you're gonna be my client?"
# ryan: i go
# ====================
#
# kris: hello, friend.
# jerry: hi, i am tycho brahe of penny arcade and pax
# jerry: i am at the dran and courtier
# jerry: today is the last day of the event
# jerry: so until that change, the last available key is
# jerry: permanent.
# jerry: you can't give it to me-- not right now.
# jerry: but for one thing.
# jerry: it's toothlessly... happy!
# jerry: eventually...
# jerry: you'll be able to find it in the
# walnut branch of the goblin's gallery.
# kate: oh, stop that.
# jerry: and then at the top of the stairs
# jerry: you'll be able to find the key to the door.
# jerry: and then, from the crow's nest
# (sound of doors opening and leaving the building)
# kris: hmm.
# jerry: now, enjoy a misty;
# jerry: the goblin's park!
# kris: it's a great game.
# patrick: it's coming up.
# jerry: check it out.
# patrick: i'm gonna
# ====================
#
# kris: hello, friend. i am yoursig. ryan: ah i see.
# kate: i see. and then i go...
# kris: i go back and forth...
# jerry: yeah, yeah. you want to...
# kris: i go back and forth and i've, "i'm going to dirty the business."
# kate: business?
# jerry: you want to...
# amy: "i don't know what that means but it's a dirty trick."
# kate: "i think it's a very dirty trick."
# kate: "i don't want to be dirty."
# i mean, dirt's a good thing.
# (laughter)
# amy: "trying to look my friend in the eye."
# kate: trying to look my friend in the eye.
# amy: "do you know what this is about?
# holes that work here?"
# kate: "okay, try to look--"
# amy: "i can't see anything wrong with it."
# kate: "but you gotta say something."
# amy: "someone to talk to."
# kate: "locally."
# amy: "okay."
#
# ====================

# %%
generate("amy: I do a bite")
# Out:
# a: I do a bite-atom attack and that is exactly what happens.
# kate: oh my, my little brain.
# jerry: yeah, exactly.
# amy: that is so nice.  kate: yay.
# jerry: k'thriss drow'b.
# kris: i'm also a monk.
# so i can't use my monk weapon
# amy: to parry a melee attack
# kris: to parry a melee attack.
# kate: oh, nice.
# jerry: and you can do a monk weapon attack but
# jerry: you cannot pull off a pirouette.
# ryan: aww.
# jerry: you have to use your action
# to attack the monk.
# ryan: i said, 'i hate this so much. i hate this so much. i'm gonna just keep going with this.'
# and then i gonna turn my attention to the monk!
# amy: oh, come with me.
# kris: what's the d&d version of it?
# kate: try it.  kris: yeah.
# ryan: try it. try it.
# jerry: yeah, version D.
# kris:
# ====================
#
# a: I do a bite... no, it's like the cauldron!
# kris: (exhausted) "i heard that you're a vampire!"
# (laughter)
# kris: "that's what i heard!"
# amy: wow!
# kate: "that's exciting!"
# kris: "that's exciting to me!"
# jerry: right. now you're up in the gallery.
# now you want to drive up there?
# jerry: yeah, i'm up there.
# kate: ooh. there's a guy there!
# ryan: he killed a horse!
# kris: dude's in the front.
# kris: don't stop him.
# ryan: he's in the back.
# kris: you gotta stop him.
# ryan: you gotta stop the guy.
# ryan: he's in the back.
# kate: he's in the back?  jerry: yeah.
# kris: you don't want to see what'sy.
# ryan: i shan't carry a cart around.
# jerry: you want to see how it goes?
# kris: well, i can tell when it's dirty.
# and then i
# ====================
#
# a: I do a bite...
# jerry: yeah, yeah.
# kris: and you just take a swing at it.
# ryan: (growling grunt)
# amy: ugh!
# kris: like it's the worst move.
# amy: but it's not dead!
# kris: just get it out of there.
# amy: but it is in there.
# jerry: then you just swing right back in...
# kris: (growling grunt)
# jerry: and it is back to human mouth.
# amy: oh naw.
# - so i go right back inside and i run into
# brandy. you don't hear anything strange going on.
# you hear...
# a) a sort of yelp, like, "thank you, friend."
# (straining) hmm?
# b) a prayer, like, "thank god we're not vampires."
# c) a tiny prayer, like, "thank god we're not vampires."
# (laughter)
# engulfed in a sweet, sweet savory stew,
# then slowly subsided.
# then leashed. then leashed and awakened.
# then awake. then awakened.
# then i'm not
# ====================
#
# a: I do a bite...
# jerry: you just send it right over his back ridge.
# kate: bite him on the nuts?
# kate: i don't even know how i feel about that.
# amy: bite his nuts.
# kate: i'm just gonna...
# i'm gonna enjoy that as a dead animal.
# amy: that's better than decapitating a mouse.
# kate: yeah.
# amy: elfs.
# amy: that's better than that...
# kate: yeah.
# kate: that's more dead than alive.
# amy: yeah. i got--
# amy: i got a ten and a half.
# kate: me a half and a half.
# ryan: ahhhh. better.
# kate: yeah yeah better.
# kris: yeah i kill them individually.
# (laughter)
# jerry: and then they become a kind
# of clump of flesh and bones.
# kate: okay. fine. that's fine.
# i've identified the mice as being
# kate: partially eaten but also still in the chicken coop
# jerry: and it's so happening.
# kate: yeah yeah, it's like
# ====================

# %%
generate("kate: sixth edition")
# Out:
# kate: sixth edition.
# jerry: yeah, yeah.   kris: yeah.
# jerry: here you go. good thing you did.
# ryan: yeah.
# jerry: thanks for the stream.
# jerry: thank you.
# kris: k.
# jerry: kris: hello.
# i am wondering if you would...
# jerry: would you mind if i made a note of that?
# kate: sure.
# jerry: assuming it's still relevant to this conversation.
# kris: let's assume it's not...
# jerry: still relevant to this conversation.
# kris: i'll take a moment to think about that.
# after we make that assumption, i will--
# kris: good idea.
# - i'll make a note of it.
# - yeah, that's a good idea. just in case it gets absorbed in your...
# ryan: (snorts)
# amy: (clears throat)
# kris: clean, white, easy going...
# ryan: yeah.
# kris:gets taken care of,
# looks great, and then...
# jerry: just positive.
# ryan: just like, "
# ====================
#
# kate: sixth edition?
# ryan: yeah. it was.
# kris: yeah, all right. well...
# amy: so...the six...
# jerry: yeah exactly. they're on their way up.
# kris: okay. they reached that point.
# kate: they reached that part of the floor?
# jerry: they both--they haven't reached--they're both below.
# kate: okay. they met there.
# jerry: yeah, yeah. they were just painting...
# kate: okay.
# kate: "this is nice. letting me know when it's ok to touch."
# "this is nice. they're having an effect."
# jerry: "i'm going to...touch the floor while they're still in the room."
# kate: okay. they've been in this room for three days.
# jerry: they've been having these
# combos? kate: yeah. they've been having these?
# jerry: yeah. he's been having...
# these...combos.
# kate: i can't think of any. i don't like them.
# jerry: yeah, yeah.
# kate: so
# ====================
#
# kate: sixth edition?    kris: it's last.
# kate: oh! yeah. yeah.
# jerry: yeah, it's last chance.
# kris: fuck it.
# jerry: yeah. you can read it if you want.
# but it's last chance.
# - oh great.
# - to my right, ryan & kris: far right; charmed,
# wizard of the close quarter.
# - yeah, yeah. that's who i am.
# - i'm the last person to get the fuck out of this.
# jerry: really?
# kris: yeah.
# kris: whoever runs this shit.
# - whoever runs this shit, yeah.
# - whoever runs this shit, yeah!
# that's the guy i'm going to hop on.
# - yeah.
# - yeah. run off with him.
# - he's on the way.
# - mhmm. okay.
# kris: i'm-- my alarm is gone.
# jerry: yeah, it's all gone but it's still dark.
# kris: and i hop on the bus.
# (appreciative sound)
# jerry: you don
# ====================
#
# kate: sixth edition!
# jerry: yeah!
# kate: oh yeah!
# jerry: it's like-- i don't know!
# kate: oh yeah!
# amy: (laughs) check it out!
# kate: it's just this-- you look at rosie, you're like,
# kate: "no, i'm full?"
# (laughter)
# kris: "what? what have i done
# that's wrongs me?"
# kate: "no, i..."
# ryan: "i feel bad. i feel bad."
# kate: "i'd really like to use one of your die.
# i'd really like to use it on something.
# i'm stumped as to why i would want to do that."
# kris: "it's hard to see the vampire."
# jerry: "a halfling would sell you a dagger in exchange for
# a doll that she could use to slice through the flesh of a helpless person."
# kate: "that's just my way of thinking it."
# kris: "you're... a little tough."
# kate: "yeah. i'm solid."
# kris: "you're a
# ====================

# %%
generate("ryan: is this impressive in d&d?")
# Out:
# r: is this impressive in d&d? by the way?
# jerry: yes.
# kris: okay.
# kate: hey.
# kris: that's a 19.
# jerry: yeah exactly. so like--
# kris: it's a 20, yeah.  ryan: right.
# jerry: yeah, i would use that. but like...
# kris: it's not garbage.  ryan: no.
# jerry: woodworkers?
# kris: it's garbage.  ryan: no.
# jerry: walnut dankgrass.
# amy: dc granny?
# jerry: you got the top two?
# kris: yeah ok.
# amy: enough chicken legs.
# jerry: you know what i mean?
# kris: so then i don't know the labor, but...
# kris: it would be pretty nice.
# if i didn't have the money to feed the family,
# i wouldn't want to be a laborer.
# kate: oh my god.  kris: i'm a chicken-2-the-bone.
# ryan: you're a chicken-the-bone?
# kris: i'm a
# ====================
#
# r: is this impressive in d&d? by the way?
# jerry: yeah exactly. i mean this is like, the d12 that washes ashore in front of me.
# and this is in addition to the um...
# d10 that i got from foremother...
# jerry: yeah, yeah.
# kris: (whispers) hello.
# kate: i'm sorry.
# amy: what?
# jerry: hello.
# amy: i'm sorry.
# amy: i'm Amy the falcon.
# amy: just holding the thing.
# jerry: she's so serious.
# amy: that's what she says.
# kris: she's just reading the whole thing.
# (laughter)
# amy: "i know what it's like to be a bear. i know what it's like to be a drow."
# jerry: she's just like, "thank you."
# kris: "hi, friend."
# kate: "hi."
# kris: "what... have you got..."
# jerry: she's trying to say, "thank you."
# here's what she's saying.
# here's what she's trying to do.
# and she's trying to
# ====================
#
# r: is this impressive in d&d? by the way?
# jerry: no, it's nice. it's appreciated.
# jerry: when someone rolls a 20,
# jerry: you have to give them a special
# note. they have to keep these notes.
# jerry: the note of the lucky one.
# amy: oh okay.
# jerry: they all did. they all failed.
# jerry: here's the thing.
# the lucky ones don't roll a die.
# ryan: so they all failed.
# jerry: on the plus side.
# amy: i got a hair of gold.
# ryan: i got a hair of gold.
# ryan: 15, 21, 22, 23.
# kris: hmm.
# jerry: they have to give you
# a positive one, you have to give them a negative one.
# jerry: that's right. you've got to give them a bonus
# and they have to do a acrobatics roll.
# amy: oh my god.
# (bronze noise)
# jerry: (stammers)
# ryan: what's the deal with you guys stealing stuff from the inn?
# jerry: this is big trouble.
# ====================
#
# r: is this impressive in d&d?
# ryan: this is like, i gotta say, more like uh...
# kate: (whispers) oh my god.
# ryan: this is like, i can't hear anything.
# kate: (whispers) not a mouth.
# ryan: no, it's like this. this is the first time...
# kate: like you mouth hurts me? like, oh okay.
# ryan: this is the first time i've
# heard anything that me i go, "oh sorry."
# ryan: i go, "uh ah" after that.
# kris: yeah. (whispers) you wouldn't know.
# jerry: no. you're like, "ah," you're like...
# kris: "i would have no complaint."
# ryan: yeah.
# kris: "i'm an inn!" i say.
# ryan: i yell. i try to
# get my attacks to those two little toes.
# amy: they're there!
# (laughter)
# kris: i cast speak with animals.
# ryan: they say, "don't eat this."
# jerry: no, they say, "don't eat this."
# kris:
# ====================

# %%
generate("bwomp bwomp", length=100, nsamples=3)
# Out:
# bwomp bwomp!
# amy: oh yeah, that's a bonus action.
# ryan: yeah, that's a bonus action.
# kris: you didn't do it, mom.
# kate: aww.
# jerry: jeez.
# kris: here's the thing.
# this is a game about numbers
# and godzilla derby. so you want the
# largest possible lineup,
# so that gives you some leeway.
# jerry: mmhmm.
# ryan
# ====================
#
# bwomp bwomp.
# amy: "i would pay to watch this."
# jerry: yeah exactly.
# kate: ok. alright.
# jerry: so some of that may come
# through onto your new friend.
# jerry: let's see how much damage
# jerry: you can do.
# kris: see? i got two points for this.
# ryan: yeah.
# kate: all right.
# kris: see ya in a few...
# kate
# ====================
#
# bwomp bwomp
# (dice rolling) womp! womp! womp!
# (everyone making noise)
# (laughter)
# amy: so you're right, folks.
# amy: i would have added more dissonant rants to my rolls.
# so scroll up on the mast?
# jerry: yeah, at the moment you're looking down...
# jerry: you see...
# amy: proud christ.
# jerry: take a look around.
# amy: right now
# ====================
